# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append('/content/drive/MyDrive/code')

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/active-learning-project-code'

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/active-learning-project-code
# Out:
# /content/drive/MyDrive/Colab Notebooks/active-learning-project-code

# %%
# !python main.py
# Out:
# ...
# ACTIVE LEARNING PROJECT
# ...
#
# [SETUP] Using device: cuda
# [UTILS] Random seed set to 42
# [GPU] Available: NVIDIA A100-SXM4-40GB
# [GPU] CUDA version: 12.6
# [SETUP] Results will be saved to: results
#
# ...
# EXPERIMENT 1: REPRODUCTION (Bayesian CNN with MC Dropout)
# ...
#
# [BAYESIAN] Running BALD...
# 100% 9.91M/9.91M [00:01<00:00, 5.67MB/s]
# 100% 28.9k/28.9k [00:00<00:00, 133kB/s]
# 100% 1.65M/1.65M [00:01<00:00, 1.25MB/s]
# 100% 4.54k/4.54k [00:00<00:00, 17.0MB/s]
#   Final accuracy: 96.74%
#   Time elapsed: 276.4 seconds
#
# [BAYESIAN] Running VARIATION_RATIOS...
#   Final accuracy: 98.23%
#   Time elapsed: 263.7 seconds
#
# [BAYESIAN] Running MAX_ENTROPY...
#   Final accuracy: 98.23%
#   Time elapsed: 264.7 seconds
#
# [BAYESIAN] Running MEAN_STD...
#   Final accuracy: 96.08%
#   Time elapsed: 263.9 seconds
#
# [BAYESIAN] Running RANDOM...
#   Final accuracy: 95.99%
#   Time elapsed: 263.3 seconds
#
# [PLOTTING] Generating Figure 1...
# Figure(1200x600)
#
# ...
